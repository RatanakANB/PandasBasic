# %%
# !pip3 install matplotlib
# !pip3 install pandas

# %%
import sys
sys.path
# Out:
# ['/Users/anbschool0027/Documents/ANB CORE Course/DataPanda/23Seriel',
#  '/Users/anbschool0027/anaconda3/envs/ANB24_RATANAK/lib/python311.zip',
#  '/Users/anbschool0027/anaconda3/envs/ANB24_RATANAK/lib/python3.11',
#  '/Users/anbschool0027/anaconda3/envs/ANB24_RATANAK/lib/python3.11/lib-dynload',
#  '',
#  '/Users/anbschool0027/anaconda3/envs/ANB24_RATANAK/lib/python3.11/site-packages']

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
marvel = ['Iron Man', 'Captain America', 'Thor', 'Winter Soldier', 'Ultron', 'Ant-Man', 'Spider-Man']
s = pd.Series(marvel)
print(s)
# Out:
# 0           Iron Man
# 1    Captain America
# 2               Thor
# 3     Winter Soldier
# 4             Ultron
# 5            Ant-Man
# 6         Spider-Man
# dtype: object

# %%
import pandas as pd
import numpy as np
n = np.arange(10, 16)
s = pd.Series(n)
print(s)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int64

# %%
import pandas as pd
import numpy as np
np. random. seed (0)
r = np. random. random(size = 6)
s = pd. Series(r)
print(s)
# Out:
# 0    0.548814
# 1    0.715189
# 2    0.602763
# 3    0.544883
# 4    0.423655
# 5    0.645894
# dtype: float64

# %%
import pandas as pd
import numpy as np
s = pd.Series (4)
print(s)
# Out:
# 0    4
# dtype: int64

# %%
import pandas as pd
s = pd. Series([1, 2, 3, 4, 5], index = ['q', 1, 'cat', 'd', 'dog'])
print(s)
# Out:
# q      1
# 1      2
# cat    3
# d      4
# dog    5
# dtype: int64

# %%
import pandas as pd
dates = pd.date_range('2021-01-01', '2021-01-07')
print (dates)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
marvel = ['Iron Man', 'Captain America', 'Thor', 'Winter Soldier', 'Ultron', 'Ant-Man', 'Spider-Man']
dates = pd.date_range('2021-01-01', '2021-01-07')
new_s = pd.Series(marvel, index=dates)
print(new_s)
# Out:
# 2021-01-01           Iron Man
# 2021-01-02    Captain America
# 2021-01-03               Thor
# 2021-01-04     Winter Soldier
# 2021-01-05             Ultron
# 2021-01-06            Ant-Man
# 2021-01-07         Spider-Man
# Freq: D, dtype: object

# %%
import pandas as pd
s = ['element1', 'element2', 'element3', 'elementA', 'element5', 'element6', 'element7', 'element8']
pd. Series(s, index = ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'))
# Out:
# a    element1
# b    element2
# c    element3
# d    elementA
# e    element5
# f    element6
# g    element7
# h    element8
# dtype: object

# %%
import pandas as pd
s = ['element1', 'element2', 'element3', 'element4', 'element5', 'elemento', 'element7', 'element8']
pd. Series (s)
# Out:
# 0    element1
# 1    element2
# 2    element3
# 3    element4
# 4    element5
# 5    elemento
# 6    element7
# 7    element8
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 marvel.values
#
# AttributeError: 'list' object has no attribute 'values'

# %%
import pandas as pd
s = ['element1', 'element2', 'element3', 'element4', 'element5', 'element6', 'element7', 'element8']
sr = pd.Series(s)
sr[2]
sr[[4, 5]]
# Out:
# 4    element5
# 5    element6
# dtype: object

# %%
import pandas as pd
s = ['element1', 'element2', 'element3', 'element4', 'element5', 'element6', 'element7', 'element8']
sr = pd. Series(s, index = ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'))
sr['c']
sr[['e', 'f']]
# Out:
# e    element5
# f    element6
# dtype: object

# %%
import pandas as pd
s = [10, 20, 30, 40, 50]
sr = pd. Series(s)
print(sr)
print(sr ** 2)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0     100
# 1     400
# 2     900
# 3    1600
# 4    2500
# dtype: int64

# %%
import pandas as pd
s = [10, 20, 30, 40, 50]
t = [23, 345, 123]
sr1 = pd.Series(s)
sr2 = pd. Series(t)
sr3 = sr1 + sr2
print(sr3)
# Out:
# 0     33.0
# 1    365.0
# 2    153.0
# 3      NaN
# 4      NaN
# dtype: float64

# %% [markdown]
# # pandas Methods

# %%
import pandas as pd
import numpy as np

np.random.seed(2)
data = np.random.randint(1, 100, 10)
s = pd.Series(data)

print("s:")
print(s)

print("count:")
print(s.count())

print("sum:")
print(s.sum())

print("mean:")
print(s.mean())

print("median:")
print(s.median())

print("mode:")
print(s.mode())

print("std:")
print(s.std())

print("min:")
print(s.min())

print("max:")
print(s.max())

print("abs:")
print(s.abs())

print("prod:")
print(s.prod())

print("cumsum:")
print(s.cumsum())

print("cumprod:")
print(s.cumprod())
# Out:
# s:
# 0    41
# 1    16
# 2    73
# 3    23
# 4    44
# 5    83
# 6    76
# 7     8
# 8    35
# 9    50
# dtype: int64
# count:
# 10
# sum:
# 449
# mean:
# 44.9
# median:
# 42.5
# mode:
# 0     8
# 1    16
# 2    23
# 3    35
# 4    41
# 5    44
# 6    50
# 7    73
# 8    76
# 9    83
# dtype: int64
# std:
# 25.87340977400028
# min:
# 8
# max:
# 83
# abs:
# 0    41
# 1    16
# 2    73
# 3    23
# 4    44
# 5    83
# 6    76
# 7     8
# 8    35
# 9    50
# dtype: int64
# prod:
# 4279834076672000
# cumsum:
# 0     41
# 1     57
# 2    130
# 3    153
# 4    197
# 5    280
# 6    356
# 7    364
# 8    399
# 9    449
# dtype: int64
# cumprod:
# 0                  41
# 1                 656
# 2               47888
# 3             1101424
# 4            48462656
# 5          4022400448
# 6        305702434048
# 7       2445619472384
# 8      85596681533440
# 9    4279834076672000
# dtype: int64

# %%
import pandas as pd
s = [10, 20, 30, 40, 50]
t = 123, 345, 123J
srl = pd.Series(s)
sr2 = pd.Series(t)
sr3 = sr1 + sr2
print(sr3)
print(sr3.count())
print(sr3.sum())
# Out:
# 0    133.0+  0.0j
# 1    365.0+  0.0j
# 2     30.0+123.0j
# 3      NaN+  0.0j
# 4      NaN+  0.0j
# dtype: complex128
# 3
# (528+123j)

# %%
import matplotlib.pyplot as plt
plt. plot([1, 2, 3, 4])
plt. show()

# %%
import matplotlib.pyplot as plt
plt. plot([1, 2, 3, 4], [1, 4, 9, 16])
plt. show()

# %%
import matplotlib.pyplot as plt
x = range(100)
y = [value **2 for value in x]

# Define line style arguments as a dictionary
line_styles = {'linewidth': 5.0, 'color': 'red'}

# Pass the dictionary to plt.plot
plt.plot(x, y, **line_styles)

plt.title('hello world of chart')
plt.ylabel('y-some numbers')
plt.xlabel('x-some numbers')
plt.show()

# %%
from matplotlib import pyplot as plt
days_in_year = [88, 225, 365, 687, 4333, 10756, 30687, 60190, 90553]
plt. bar (range(len(days_in_year)), days_in_year)
plt. show()

# %%
import pandas as pd
marvel = ['Iron Man' ,'Captain America', 'Thor', 'Winter Soldier', 'Ultron', 'Ant-Man', 'Spider-Man']
s = pd. Series(marvel)

# %%
s.values
# Out:
# array(['Iron Man', 'Captain America', 'Thor', 'Winter Soldier', 'Ultron',
#        'Ant-Man', 'Spider-Man'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
import pandas as pd
s = ['element1', 'element2', 'element3', 'element4', 'element5', 'element6', 'element7', 'element8']
sr = pd.Series(s)
sr[2]
sr[[4, 5]]
# Out:
# 4    element5
# 5    element6
# dtype: object

# %%
import pandas as pd
s = ['element1', 'element2' , 'element3', 'element4', 'element5', 'element6', 'element7', 'element8']
sr = pd. Series(s, index = ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'))
sr['c']
sr[['e', 'f']]
# Out:
# e    element5
# f    element6
# dtype: object

# %%
import pandas as pd
s = 110, 20, 30, 40, 50J
sr = pd.Series(s)
print(sr)
print(sr ** 2)
# Out:
# 0    110.0+  0.0j
# 1     20.0+  0.0j
# 2     30.0+  0.0j
# 3     40.0+  0.0j
# 4      0.0+ 50.0j
# dtype: complex128
# 0    12100.0+    0.0j
# 1      400.0+    0.0j
# 2      900.0+    0.0j
# 3     1600.0+    0.0j
# 4    -2500.0+    0.0j
# dtype: complex128

# %%
import pandas as pd
s = [10, 20, 30, 40, 50]
t = [23, 345, 123]
sr1 = pd.Series(s)
sr2 = pd. Series(t)
sr3 = sr1 + sr2
print(sr3)
# Out:
# 0     33.0
# 1    365.0
# 2    153.0
# 3      NaN
# 4      NaN
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Population data for 2020 and 2021
population_2020 = {
    'Tokyo': 37339804, 'Delhi': 31181376, 'Shanghai': 27795702, 'Sao Paulo': 22237472, 
    'Mexico City': 21918936, 'Dhaka': 21741090, 'Cairo': 21322750, 'Karachi': 16459472, 
    'Istanbul': 15415197, 'Buenos Aires': 15257673, 'Kinshasa': 14970460, 'Lagos': 14862111, 
    'Manila': 14158573, 'Rio de Janeiro': 13544462, 'Moscow': 12593252, 'Bogota': 11167392, 
    'Paris': 11078546, 'Jakarta': 10915364, 'Lima': 10882757
}

population_2021 = {
    'Tokyo': 37393128, 'Delhi': 30290936, 'Shanghai': 27058480, 'Sao Paulo': 22043028, 
    'Mexico City': 21782378, 'Dhaka': 21005860, 'Cairo': 20900604, 'Karachi': 16093786, 
    'Istanbul': 15190336, 'Buenos Aires': 15153729, 'Kinshasa': 14342439, 'Lagos': 14368332, 
    'Manila': 13923452, 'Rio de Janeiro': 13458075, 'Moscow': 12537954, 'Bogota': 10978360, 
    'Paris': 11017230, 'Jakarta': 10770487, 'Lima': 10719188
}

# City area data
city_area = {
    'Tokyo': 2194, 'Delhi': 1484, 'Shanghai': 6340, 'Sao Paulo': 1521, 'Mexico City': 1485, 
    'Dhaka': 306.4, 'Cairo': 3085, 'Karachi': 3780, 'Istanbul': 5343, 'Buenos Aires': 203, 
    'Kinshasa': 9965, 'Lagos': 1171, 'Manila': 42.88, 'Rio de Janeiro': 1255, 'Moscow': 2511, 
    'Bogota': 1775, 'Paris': 105.4, 'Jakarta': 661.5, 'Lima': 2672
}

# Convert dictionary data into series objects
s_2020 = pd.Series(population_2020)
s_2021 = pd.Series(population_2021)
s_area = pd.Series(city_area)

# Calculate the population change for each city
growth = s_2020 - s_2021
print('<Increase or Decrease in the population>')
print(growth)

# Represent the population change using a bar graph
plt.figure(figsize=(10, 6))
plt.barh(growth.index, growth.values, color='skyblue')
plt.xlabel('Population Change')
plt.title('Population Change from 2020 to 2021')
plt.xticks(rotation='vertical', size=8)
plt.show()

# Calculate the population density by capital for each country
population_density = s_2020 / s_area
print('<Population Density>')
print(population_density)

# Represent the population density using a bar graph
plt.figure(figsize=(10, 6))
plt.barh(population_density.index, population_density.values, color='orange')
plt.xlabel('Population Density (people per sq. km)')
plt.title('Population Density in 2020')
plt.xticks(rotation='vertical', size=8)
plt.show()

# Print the maximum and minimum population densities
max_density_city = population_density.idxmax()
max_density_value = population_density.max()
min_density_city = population_density.idxmin()
min_density_value = population_density.min()

print(f'The city with the maximum population density is {max_density_city} with {max_density_value:.2f} people per sq. km.')
print(f'The city with the minimum population density is {min_density_city} with {min_density_value:.2f} people per sq. km.')
# Out:
# <Increase or Decrease in the population>
# Tokyo             -53324
# Delhi             890440
# Shanghai          737222
# Sao Paulo         194444
# Mexico City       136558
# Dhaka             735230
# Cairo             422146
# Karachi           365686
# Istanbul          224861
# Buenos Aires      103944
# Kinshasa          628021
# Lagos             493779
# Manila            235121
# Rio de Janeiro     86387
# Moscow             55298
# Bogota            189032
# Paris              61316
# Jakarta           144877
# Lima              163569
# dtype: int64
# <Population Density>
# Tokyo              17019.053783
# Delhi              21011.708895
# Shanghai            4384.180126
# Sao Paulo          14620.297173
# Mexico City        14760.226263
# Dhaka              70956.560052
# Cairo               6911.750405
# Karachi             4354.357672
# Istanbul            2885.120157
# Buenos Aires       75160.950739
# Kinshasa            1502.304064
# ...
